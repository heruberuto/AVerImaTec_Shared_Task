# %%
# %pip install gdown
# Out:
# ...
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !cd /mnt/data/factcheck/averimatec/Knowledge_Store/train && unzip text_related && unzip image_related
# Out:
# Archive:  text_related.zip
#    creating: text_related/image_related_store_text_train/
#   inflating: text_related/image_related_store_text_train/710.json
#   inflating: text_related/image_related_store_text_train/375.json
#   inflating: text_related/image_related_store_text_train/513.json
#   inflating: text_related/image_related_store_text_train/272.json
#   inflating: text_related/image_related_store_text_train/429.json
#   inflating: text_related/image_related_store_text_train/324.json
#   inflating: text_related/image_related_store_text_train/468.json
#   inflating: text_related/image_related_store_text_train/387.json
#   inflating: text_related/image_related_store_text_train/740.json
#   inflating: text_related/image_related_store_text_train/112.json
#   inflating: text_related/image_related_store_text_train/736.json
#   inflating: text_related/image_related_store_text_train/323.json
#   inflating: text_related/image_related_store_text_train/524.json
# ...
